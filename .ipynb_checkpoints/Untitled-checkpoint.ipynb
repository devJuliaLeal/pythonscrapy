# %%
import requests
from bs4 import BeatifulSoup

# %%
headers={'user-agent': 'Mozilla/5.0'}

resposta = requests.get ('https://landing.jobs/jobs?hd=false&t_co=false&t_st=false&utm_source=google&utm_medium=cpc&utm_campaign=T_AlwaysON&utm_term=it%20jobs&utm_content=generic_br_pt', 
                         headers = headers)
resposta.text
# Out:
# '<!DOCTYPE html><html lang="en"><head><script defer="defer" src="https://www.google.com/recaptcha/api.js"></script><meta content="no-cache" name="turbolinks-cache-control" /><meta charset="utf-8" /><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport" /><meta content="v6174" itemprop="version" /><meta content="AIzaSyAFiTqddUYMSGpDWwQgg-SpiUASkKlIn1U" itemprop="google-maps-api-key" /><meta content="IE=edge" http-equiv="X-UA-Compatible" />\n<script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"NRJS-92691caae576c4d8b44","applicationID":"579295284","transactionName":"JloMRhcJW1lTS04LVwdqA1YWSV5bUlwZ","queueTime":6,"applicationTime":63,"agent":""}</script>\n<script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-92691caae576c4d8b44",applicationID:"5792
# ...
